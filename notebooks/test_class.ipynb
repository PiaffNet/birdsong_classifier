# %%
from birdsong.config import config
from birdsong.audiotransform.to_image import AudioPreprocessor

# %%
test_input_path = '/Users/aless/code/A54P/birdsong_classifier/data/birdsong_test_input/'
test_output_path = '/Users/aless/code/A54P/birdsong_classifier/data/class_test/'

test_class = AudioPreprocessor(test_input_path,test_output_path,config.SPECTOGRAM_TYPE, config.OUTPUT_FORMAT)

# %%
test_class.__dict__
# Out:
# {'input_folder': '/Users/aless/code/A54P/birdsong_classifier/data/birdsong_test_input/',
#  'output_folder': '/Users/aless/code/A54P/birdsong_classifier/data/class_test/',
#  'spectogram_type': 'MEL',
#  'output_format': 'png'}

# %%
test_class.create_data()
# Out:
# prepare processing of /Users/aless/code/A54P/birdsong_classifier/data/birdsong_test_input/banswa/XC140283_189.mp3
# i am here !
# ha-ha-ha XC140283_189
# target output path : /Users/aless/code/A54P/birdsong_classifier/data/class_test/banswa/XC140283_189png
# --------------------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/code/A54P/birdsong_classifier/birdsong/audiotransform/to_image.py:104, in AudioPreprocessor.preprocess_audio(self, file_path, target_directory)
#     103 # Step 1: Resample audio to target sample rate and convert from stereo to mono
# --> 104 audio = audio.resample(sample_rate_Hz=config.SAMPLING_RATE,
#     105                     channels=1) # channel=1 for mono
#     107 # Step 2: transform cleaned audio file into spectogram (ndarray)
#
# AttributeError: 'AudioSegment' object has no attribute 'resample'
#
# ...

# %%
import glob
import os

# %%
tot = os.path.join('/Users/aless/code/A54P/birdsong_classifier/data/birdsong_test_input/banswa/','*.mp3')

# %%
glob.glob(tot)
# Out:
# ['/Users/aless/code/A54P/birdsong_classifier/data/birdsong_test_input/banswa/XC140283_189.mp3',
#  '/Users/aless/code/A54P/birdsong_classifier/data/birdsong_test_input/banswa/XC140282_59.mp3',
#  '/Users/aless/code/A54P/birdsong_classifier/data/birdsong_test_input/banswa/XC304877_20.mp3',
#  '/Users/aless/code/A54P/birdsong_classifier/data/birdsong_test_input/banswa/XC372304_91.mp3',
#  '/Users/aless/code/A54P/birdsong_classifier/data/birdsong_test_input/banswa/XC140282_71.mp3',
#  '/Users/aless/code/A54P/birdsong_classifier/data/birdsong_test_input/banswa/XC184443_2.mp3',
#  '/Users/aless/code/A54P/birdsong_classifier/data/birdsong_test_input/banswa/XC372304_85.mp3',
#  '/Users/aless/code/A54P/birdsong_classifier/data/birdsong_test_input/banswa/XC140282_65.mp3',
#  '/Users/aless/code/A54P/birdsong_classifier/data/birdsong_test_input/banswa/XC304877_34.mp3',
#  '/Users/aless/code/A54P/birdsong_classifier/data/birdsong_test_input/banswa/XC370740_0.mp3',
# ...
